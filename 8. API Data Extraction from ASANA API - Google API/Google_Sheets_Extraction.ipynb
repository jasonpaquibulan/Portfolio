# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import gspread
import pandas as pd
from oauth2client.service_account import ServiceAccountCredentials

# Load credentials
scope = ["https://spreadsheets.google.com/feeds",'https://www.googleapis.com/auth/spreadsheets',"https://www.googleapis.com/auth/drive.file","https://www.googleapis.com/auth/drive"]
credentials = ServiceAccountCredentials.from_json_keyfile_name("/content/drive/MyDrive/Google API/hardy-city-396013-951f05d8226b.json", scope)
gc = gspread.authorize(credentials)

# Open the Google Spreadsheet using its title

#SPREADSHEET NAMES ['RES| FIXED RATE - LIVE','']

spreadsheet_title = 'RES| FIXED RATE - LIVE'
worksheet = gc.open(spreadsheet_title).sheet1  # You can also use get_worksheet() to select a specific worksheet

# Get all values from the worksheet
data = worksheet.get_all_values()

# Convert the data to a DataFrame
headers = data[0]  # Assuming the first row contains headers
df = pd.DataFrame(data[1:], columns=headers)

# print(spread_sheet)

# %%
df[['Name','DU Shortname','Section/Column','Start Date', 'Due Date']]
# Out:
#                                                 Name DU Shortname  \
# 0                             557 Feather Meal Corp.    TRLCO2MSP
# 1                      Light Rail Manila Corporation     MRLCOMSP
# 2                                Fast Services Corp.      VECOMSP
# 3                  Creative Diecast Philippines Corp     MRLCOMSP
# 4                               Vitarich Corporation     MRLCOMSP
# 5                               Pioneer Centre, Inc.     MRLCOMSP
# 6      Heva Management & Development Corp. 3 (Rizal)     MRLCOMSP
# 7           Eight Integrated Development Corporation      CEDCMSP
# 8   Polaris Corporate Center Condominium Corporation     MRLCOMSP
# 9                   Aeonprime Land Development Corp.     MRLCOMSP
# 10                  King's Quality Foods (Cebu) Inc.      VECOMSP
# 11                     Yiking Plastic Production Inc       LEZMSP
# 12              Gunma Gohkin Philippines Corporation     MRLCOMSP
# ...
