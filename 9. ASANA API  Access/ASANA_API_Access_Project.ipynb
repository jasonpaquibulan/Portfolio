# %%
# !pip install asana
# Out:
# Collecting asana
#   Downloading asana-5.0.3-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.3/176.3 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from asana) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from asana) (2.8.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from asana) (1.16.0)
# Requirement already satisfied: urllib3>=1.23 in /usr/local/lib/python3.10/dist-packages (from asana) (2.0.7)
# Installing collected packages: asana
# Successfully installed asana-5.0.3

# %%
import asana
from asana.rest import ApiException
from pprint import pprint

PAT = '' # attach PAT here

configuration = asana.Configuration()
configuration.access_token = PAT
api_client = asana.ApiClient(configuration)

# create an instance of the API class
projects_api_instance = asana.ProjectsApi(api_client)
project_gid = " " # str | Globally unique identifier for the project. #attach project_gid here
opts = {
    'opt_fields': "archived,color,completed,completed_at,completed_by,completed_by.name,created_at,created_from_template,created_from_template.name,current_status,current_status.author,current_status.author.name,current_status.color,current_status.created_at,current_status.created_by,current_status.created_by.name,current_status.html_text,current_status.modified_at,current_status.text,current_status.title,current_status_update,current_status_update.resource_subtype,current_status_update.title,custom_field_settings,custom_field_settings.custom_field,custom_field_settings.custom_field.asana_created_field,custom_field_settings.custom_field.created_by,custom_field_settings.custom_field.created_by.name,custom_field_settings.custom_field.currency_code,custom_field_settings.custom_field.custom_label,custom_field_settings.custom_field.custom_label_position,custom_field_settings.custom_field.date_value,custom_field_settings.custom_field.date_value.date,custom_field_settings.custom_field.date_value.date_time,custom_field_settings.custom_field.description,custom_field_settings.custom_field.display_value,custom_field_settings.custom_field.enabled,custom_field_settings.custom_field.enum_options,custom_field_settings.custom_field.enum_options.color,custom_field_settings.custom_field.enum_options.enabled,custom_field_settings.custom_field.enum_options.name,custom_field_settings.custom_field.enum_value,custom_field_settings.custom_field.enum_value.color,custom_field_settings.custom_field.enum_value.enabled,custom_field_settings.custom_field.enum_value.name,custom_field_settings.custom_field.format,custom_field_settings.custom_field.has_notifications_enabled,custom_field_settings.custom_field.is_formula_field,custom_field_settings.custom_field.is_global_to_workspace,custom_field_settings.custom_field.is_value_read_only,custom_field_settings.custom_field.multi_enum_values,custom_field_settings.custom_field.multi_enum_values.color,custom_field_settings.custom_field.multi_enum_values.enabled,custom_field_settings.custom_field.multi_enum_values.name,custom_field_settings.custom_field.name,custom_field_settings.custom_field.number_value,custom_field_settings.custom_field.people_value,custom_field_settings.custom_field.people_value.name,custom_field_settings.custom_field.precision,custom_field_settings.custom_field.resource_subtype,custom_field_settings.custom_field.text_value,custom_field_settings.custom_field.type,custom_field_settings.is_important,custom_field_settings.parent,custom_field_settings.parent.name,custom_field_settings.project,custom_field_settings.project.name,custom_fields,custom_fields.date_value,custom_fields.date_value.date,custom_fields.date_value.date_time,custom_fields.display_value,custom_fields.enabled,custom_fields.enum_options,custom_fields.enum_options.color,custom_fields.enum_options.enabled,custom_fields.enum_options.name,custom_fields.enum_value,custom_fields.enum_value.color,custom_fields.enum_value.enabled,custom_fields.enum_value.name,custom_fields.is_formula_field,custom_fields.multi_enum_values,custom_fields.multi_enum_values.color,custom_fields.multi_enum_values.enabled,custom_fields.multi_enum_values.name,custom_fields.name,custom_fields.number_value,custom_fields.resource_subtype,custom_fields.text_value,custom_fields.type,default_access_level,default_view,due_date,due_on,followers,followers.name,html_notes,icon,members,members.name,minimum_access_level_for_customization,minimum_access_level_for_sharing,modified_at,name,notes,owner,permalink_url,project_brief,public,start_on,team,team.name,workspace,workspace.name", # list[str] | This endpoint returns a compact resource, which excludes some properties by default. To include those optional properties, set this query parameter to a comma-separated list of the properties you wish to include.
    # 'opt_fields': "completed_by.name", # list[str] |
    }

try:
    # Get a project
    api_response = projects_api_instance.get_project(project_gid, opts)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling ProjectsApi->get_project: %s\n" % e)
# Out:
# {'archived': False,
#  'color': 'light-orange',
#  'completed': False,
#  'completed_at': None,
#  'completed_by': None,
#  'created_at': '2023-08-29T11:55:18.723Z',
#  'created_from_template': None,
#  'current_status': None,
#  'current_status_update': None,
#  'custom_field_settings': [{'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': 'Category of '
#                                                             'request the '
#                                                             'customer is '
#                                                             'asking for',
#                                              'enum_options': [{'color': 'yellow-orange',
#                                                                'enabled': True,
#                                                                'gid': '1205371003789308',
#                                                                'name': 'Manufacturing'},
#                                                               {'color': 'red',
#                                                                'enabled': False,
#                                                                'gid': '1205371003789309',
#                                                                'name': 'Bug'},
#                                                               {'color': 'green',
#                                                                'enabled': True,
#                                                                'gid': '1205371003789310',
#                                                                'name': 'Tourism'},
#                                                               {'color': 'indigo',
#                                                                'enabled': True,
#                                                                'gid': '1205371003789311',
#                                                                'name': 'Real '
#                                                                        'Estate'},
#                                                               {'color': 'blue',
#                                                                'enabled': True,
#                                                                'gid': '1205371003789312',
#                                                                'name': 'IT, '
#                                                                        'BPO, '
#                                                                        'Business '
#                                                                        'Services'},
#                                                               {'color': 'magenta',
#                                                                'enabled': True,
#                                                                'gid': '1205371003789313',
#                                                                'name': 'Healthcare'},
#                                                               {'color': 'red',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297372',
#                                                                'name': 'Agriculture'},
#                                                               {'color': 'orange',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297373',
#                                                                'name': 'Government '
#                                                                        'Institution'},
#                                                               {'color': 'yellow',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297374',
#                                                                'name': 'School '
#                                                                        'or '
#                                                                        'University'},
#                                                               {'color': 'yellow-green',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297375',
#                                                                'name': 'Construction'},
#                                                               {'color': 'blue-green',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297376',
#                                                                'name': 'Banking '
#                                                                        'and '
#                                                                        'Finance'},
#                                                               {'color': 'aqua',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297377',
#                                                                'name': 'Transportation '
#                                                                        'and '
#                                                                        'Storage'},
#                                                               {'color': 'purple',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297378',
#                                                                'name': 'Hotels '
#                                                                        'and '
#                                                                        'Restaurant'},
#                                                               {'color': 'hot-pink',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297379',
#                                                                'name': 'Food '
#                                                                        'Process'},
#                                                               {'color': 'pink',
#                                                                'enabled': True,
#                                                                'gid': '1205376880455346',
#                                                                'name': 'Malls'},
#                                                               {'color': 'cool-gray',
#                                                                'enabled': True,
#                                                                'gid': '1205376880455361',
#                                                                'name': 'Other '
#                                                                        'Services'}],
#                                              'gid': '1205371003789307',
#                                              'has_notifications_enabled': False,
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': True,
#                                              'is_value_read_only': False,
#                                              'name': 'Industry',
#                                              'resource_subtype': 'enum',
#                                              'type': 'enum'},
#                             'gid': '1205371003789314',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': '',
#                                              'enum_options': [{'color': 'green',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297381',
#                                                                'name': 'TMC'},
#                                                               {'color': 'blue',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297382',
#                                                                'name': 'MNL'},
#                                                               {'color': 'yellow',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297383',
#                                                                'name': 'RRL'},
#                                                               {'color': 'green',
#                                                                'enabled': False,
#                                                                'gid': '1205371004297384',
#                                                                'name': 'MHL'},
#                                                               {'color': 'none',
#                                                                'enabled': False,
#                                                                'gid': '1205371004297385',
#                                                                'name': 'LAL'}],
#                                              'gid': '1205371004297380',
#                                              'has_notifications_enabled': False,
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Account Manager',
#                                              'resource_subtype': 'enum',
#                                              'type': 'enum'},
#                             'gid': '1205371004297386',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': '',
#                                              'gid': '1205371004297391',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Actual',
#                                              'resource_subtype': 'date',
#                                              'type': 'date'},
#                             'gid': '1205371004297392',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'currency_code': None,
#                                              'custom_label': None,
#                                              'custom_label_position': None,
#                                              'description': '',
#                                              'format': 'none',
#                                              'gid': '1205371004297400',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Fixed Rate',
#                                              'precision': 2,
#                                              'resource_subtype': 'number',
#                                              'type': 'number'},
#                             'gid': '1205371004297401',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': '',
#                                              'enum_options': [{'color': 'green',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297419',
#                                                                'name': 'LUZON'},
#                                                               {'color': 'red',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297420',
#                                                                'name': 'VISAYAS'},
#                                                               {'color': 'orange',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297421',
#                                                                'name': 'MINDANAO'}],
#                                              'gid': '1205371004297418',
#                                              'has_notifications_enabled': False,
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Grid',
#                                              'resource_subtype': 'enum',
#                                              'type': 'enum'},
#                             'gid': '1205371004297422',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': '',
#                                              'enum_options': [{'color': 'green',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297424',
#                                                                'name': 'YES'},
#                                                               {'color': 'red',
#                                                                'enabled': True,
#                                                                'gid': '1205371004297425',
#                                                                'name': 'NO'}],
#                                              'gid': '1205371004297423',
#                                              'has_notifications_enabled': False,
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'PEZA',
#                                              'resource_subtype': 'enum',
#                                              'type': 'enum'},
#                             'gid': '1205371004297426',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'currency_code': None,
#                                              'custom_label': None,
#                                              'custom_label_position': None,
#                                              'description': '',
#                                              'format': 'none',
#                                              'gid': '1205376875681470',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Contract Capacity (kW)',
#                                              'precision': 0,
#                                              'resource_subtype': 'number',
#                                              'type': 'number'},
#                             'gid': '1205376875681471',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': '',
#                                              'enum_options': [{'color': 'green',
#                                                                'enabled': True,
#                                                                'gid': '1205376875681475',
#                                                                'name': 'Exclusive'},
#                                                               {'color': 'red',
#                                                                'enabled': True,
#                                                                'gid': '1205376875681476',
#                                                                'name': 'Non-Exclusive'}],
#                                              'gid': '1205376875681474',
#                                              'has_notifications_enabled': False,
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Line Rental',
#                                              'resource_subtype': 'enum',
#                                              'type': 'enum'},
#                             'gid': '1205376875681477',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': 'declared by IEMOP',
#                                              'gid': '1205376875681480',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Customer Node',
#                                              'resource_subtype': 'text',
#                                              'type': 'text'},
#                             'gid': '1205376875681481',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': 'Based on CRSS',
#                                              'gid': '1205376875681482',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'SIN',
#                                              'resource_subtype': 'text',
#                                              'type': 'text'},
#                             'gid': '1205376880455238',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': '',
#                                              'gid': '1205376880455239',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'SEIN',
#                                              'resource_subtype': 'text',
#                                              'type': 'text'},
#                             'gid': '1205376880455240',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': 'Based on CRSS',
#                                              'gid': '1205376880455241',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'GOTP',
#                                              'resource_subtype': 'text',
#                                              'type': 'text'},
#                             'gid': '1205376880455242',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': 'Customer Point of '
#                                                             'Contact',
#                                              'gid': '1205376880455244',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Contact Person',
#                                              'resource_subtype': 'text',
#                                              'type': 'text'},
#                             'gid': '1205376880455245',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': 'Customer Point of '
#                                                             'Contact',
#                                              'gid': '1205376880455246',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Contact Number',
#                                              'resource_subtype': 'text',
#                                              'type': 'text'},
#                             'gid': '1205376880455247',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': 'Customer Point of '
#                                                             'Contact',
#                                              'gid': '1205376880455248',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Email',
#                                              'resource_subtype': 'text',
#                                              'type': 'text'},
#                             'gid': '1205376880455249',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': 'Affiliated DU',
#                                              'gid': '1205376880455252',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Contact Person',
#                                              'resource_subtype': 'text',
#                                              'type': 'text'},
#                             'gid': '1205376880455253',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': 'Affiliated DU',
#                                              'gid': '1205376880455254',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Contact Number',
#                                              'resource_subtype': 'text',
#                                              'type': 'text'},
#                             'gid': '1205376880455255',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1203497384837892',
#                                                             'name': 'Bryan '
#                                                                     'Dimayuga'},
#                                              'description': 'Affiliated DU',
#                                              'gid': '1205376880455256',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Email',
#                                              'resource_subtype': 'text',
#                                              'type': 'text'},
#                             'gid': '1205376880455257',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1205392488469223',
#                                                             'name': 'Jolina '
#                                                                     'Limosnero'},
#                                              'description': 'declared by IEMOP',
#                                              'gid': '1205579750706589',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Shortname',
#                                              'resource_subtype': 'text',
#                                              'type': 'text'},
#                             'gid': '1205579750706590',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1129267587326102',
#                                                             'name': 'Michael '
#                                                                     'Angelo H. '
#                                                                     'Lasam'},
#                                              'description': '',
#                                              'enum_options': [{'color': 'green',
#                                                                'enabled': True,
#                                                                'gid': '1205637992150947',
#                                                                'name': 'With'},
#                                                               {'color': 'red',
#                                                                'enabled': True,
#                                                                'gid': '1205637992150948',
#                                                                'name': 'Without'}],
#                                              'gid': '1205637992150946',
#                                              'has_notifications_enabled': False,
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'SBLC',
#                                              'resource_subtype': 'enum',
#                                              'type': 'enum'},
#                             'gid': '1205637992150949',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1129267587326102',
#                                                             'name': 'Michael '
#                                                                     'Angelo H. '
#                                                                     'Lasam'},
#                                              'description': '',
#                                              'enum_options': [{'color': 'green',
#                                                                'enabled': True,
#                                                                'gid': '1205812144855975',
#                                                                'name': '1 MW '
#                                                                        'Above'},
#                                                               {'color': 'red',
#                                                                'enabled': True,
#                                                                'gid': '1205812144855976',
#                                                                'name': '750 kW '
#                                                                        '- 1 '
#                                                                        'MW'},
#                                                               {'color': 'orange',
#                                                                'enabled': True,
#                                                                'gid': '1205812144855977',
#                                                                'name': '500 kW '
#                                                                        '- 749 '
#                                                                        'kW'},
#                                                               {'color': 'yellow-orange',
#                                                                'enabled': True,
#                                                                'gid': '1205812144855978',
#                                                                'name': '100 kW '
#                                                                        '- 499 '
#                                                                        'kW'}],
#                                              'gid': '1205812144855974',
#                                              'has_notifications_enabled': False,
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': True,
#                                              'is_value_read_only': False,
#                                              'name': 'Threshold',
#                                              'resource_subtype': 'enum',
#                                              'type': 'enum'},
#                             'gid': '1205812144856026',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1205392488469223',
#                                                             'name': 'Jolina '
#                                                                     'Limosnero'},
#                                              'description': '',
#                                              'enum_options': [{'color': 'green',
#                                                                'enabled': True,
#                                                                'gid': '1206043560975114',
#                                                                'name': 'SCPC'},
#                                                               {'color': 'red',
#                                                                'enabled': True,
#                                                                'gid': '1206043560975115',
#                                                                'name': 'TVI'},
#                                                               {'color': 'orange',
#                                                                'enabled': True,
#                                                                'gid': '1206577128890023',
#                                                                'name': 'SIAEC'}],
#                                              'gid': '1206043560975113',
#                                              'has_notifications_enabled': False,
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Gen Node',
#                                              'resource_subtype': 'enum',
#                                              'type': 'enum'},
#                             'gid': '1206043560975116',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1205392488469223',
#                                                             'name': 'Jolina '
#                                                                     'Limosnero'},
#                                              'description': 'email for billing '
#                                                             'purposes',
#                                              'gid': '1206062604365456',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Billing',
#                                              'resource_subtype': 'text',
#                                              'type': 'text'},
#                             'gid': '1206062604365457',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1129267587326102',
#                                                             'name': 'Michael '
#                                                                     'Angelo H. '
#                                                                     'Lasam'},
#                                              'currency_code': None,
#                                              'custom_label': None,
#                                              'custom_label_position': None,
#                                              'description': '',
#                                              'format': 'none',
#                                              'gid': '1206099444508134',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Peak Demand',
#                                              'precision': 2,
#                                              'resource_subtype': 'number',
#                                              'type': 'number'},
#                             'gid': '1206099444508135',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1129267587326102',
#                                                             'name': 'Michael '
#                                                                     'Angelo H. '
#                                                                     'Lasam'},
#                                              'description': '',
#                                              'gid': '1206099444508136',
# ...
#                                              'enum_options': [{'color': 'orange',
#                                                                'enabled': True,
#                                                                'gid': '1206177248903721',
#                                                                'name': 'None'},
#                                                               {'color': 'red',
#                                                                'enabled': True,
#                                                                'gid': '1206177248903722',
#                                                                'name': 'Term '
#                                                                        'Sheet'},
#                                                               {'color': 'green',
#                                                                'enabled': True,
#                                                                'gid': '1206177248903723',
#                                                                'name': 'RSC'},
#                                                               {'color': 'yellow-orange',
#                                                                'enabled': True,
#                                                                'gid': '1206177248903724',
#                                                                'name': 'Extension '
#                                                                        'Letter'}],
#                                              'gid': '1206177248903720',
#                                              'has_notifications_enabled': False,
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Status',
#                                              'resource_subtype': 'enum',
#                                              'type': 'enum'},
#                             'gid': '1206177248903725',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1205392488469223',
#                                                             'name': 'Jolina '
#                                                                     'Limosnero'},
#                                              'description': '',
#                                              'enum_options': [{'color': 'green',
#                                                                'enabled': True,
#                                                                'gid': '1206276629520127',
#                                                                'name': 'Milling '
#                                                                        'Corporation'},
#                                                               {'color': 'orange',
#                                                                'enabled': True,
#                                                                'gid': '1206276629520128',
#                                                                'name': 'Hotel '
#                                                                        '& '
#                                                                        'Restaurant'},
#                                                               {'color': 'yellow-orange',
#                                                                'enabled': True,
#                                                                'gid': '1206276629520129',
#                                                                'name': 'Steel '
#                                                                        'Manufacturing'},
#                                                               {'color': 'yellow',
#                                                                'enabled': True,
#                                                                'gid': '1206276629520130',
#                                                                'name': 'School'},
#                                                               {'color': 'yellow-green',
#                                                                'enabled': True,
#                                                                'gid': '1206276629520131',
#                                                                'name': 'Packaging '
#                                                                        'Service '
#                                                                        'Manufacturing'},
#                                                               {'color': 'blue-green',
#                                                                'enabled': True,
#                                                                'gid': '1206276629520132',
#                                                                'name': 'Agricultural '
#                                                                        'Products '
#                                                                        'Manufacturing'},
#                                                               {'color': 'aqua',
#                                                                'enabled': True,
#                                                                'gid': '1206276629520133',
#                                                                'name': 'Supermarket'},
#                                                               {'color': 'blue',
#                                                                'enabled': True,
#                                                                'gid': '1206276629520134',
#                                                                'name': 'Plastic '
#                                                                        'Manufacturing'},
#                                                               {'color': 'indigo',
#                                                                'enabled': True,
#                                                                'gid': '1206276629520135',
#                                                                'name': 'Electronic '
#                                                                        'Products '
#                                                                        'Manufacturing'},
#                                                               {'color': 'purple',
#                                                                'enabled': True,
#                                                                'gid': '1206276629520136',
#                                                                'name': 'Government '
#                                                                        'Entities'},
#                                                               {'color': 'magenta',
#                                                                'enabled': True,
#                                                                'gid': '1206276629520137',
#                                                                'name': 'Food '
#                                                                        'Manufacturing'},
#                                                               {'color': 'hot-pink',
#                                                                'enabled': True,
#                                                                'gid': '1206276629520138',
#                                                                'name': 'Mall'},
#                                                               {'color': 'pink',
#                                                                'enabled': True,
#                                                                'gid': '1206276629520139',
#                                                                'name': 'Other '
#                                                                        'Manufacturing'},
#                                                               {'color': 'cool-gray',
#                                                                'enabled': True,
#                                                                'gid': '1206276629520140',
#                                                                'name': 'Real '
#                                                                        'Estate'},
#                                                               {'color': 'none',
#                                                                'enabled': True,
#                                                                'gid': '1206276629520141',
#                                                                'name': 'Others'}],
#                                              'gid': '1206276629520126',
#                                              'has_notifications_enabled': False,
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': 'Industry_',
#                                              'resource_subtype': 'enum',
#                                              'type': 'enum'},
#                             'gid': '1206276629520142',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}},
#                            {'custom_field': {'asana_created_field': None,
#                                              'created_by': {'gid': '1205392488469223',
#                                                             'name': 'Jolina '
#                                                                     'Limosnero'},
#                                              'currency_code': None,
#                                              'custom_label': None,
#                                              'custom_label_position': None,
#                                              'description': '',
#                                              'format': 'none',
#                                              'gid': '1206354854655462',
#                                              'is_formula_field': False,
#                                              'is_global_to_workspace': False,
#                                              'is_value_read_only': False,
#                                              'name': '% Load Factor',
#                                              'precision': 0,
#                                              'resource_subtype': 'number',
#                                              'type': 'number'},
#                             'gid': '1206354854655463',
#                             'is_important': True,
#                             'parent': {'gid': '1205371003789292',
#                                        'name': 'RES| FIXED RATE - LIVE'},
#                             'project': {'gid': '1205371003789292',
#                                         'name': 'RES| FIXED RATE - LIVE'}}],
#  'custom_fields': [],
#  'default_access_level': 'editor',
#  'default_view': 'list',
#  'due_date': None,
#  'due_on': None,
#  'followers': [{'gid': '1203497384837892', 'name': 'Bryan Dimayuga'},
#                {'gid': '1129267587326102', 'name': 'Michael Angelo H. Lasam'},
#                {'gid': '1205392488469223', 'name': 'Jolina Limosnero'},
#                {'gid': '1205676111441160', 'name': 'Raphael Ernesto Tuazon'},
#                {'gid': '1205713538292233', 'name': 'Jason Paquibulan'},
#                {'gid': '1202172752906635', 'name': 'Michael Pluma'},
#                {'gid': '1205779409810828', 'name': 'Mariadel Bagay'},
#                {'gid': '1205779409810976', 'name': 'Louie Mark Quizon'},
#                {'gid': '1204664450777161', 'name': 'Ariel B. Bautista'},
#                {'gid': '1201945980528275',
#                 'name': 'teodorico.cortinas@vivant.com.ph'},
#                {'gid': '1200860877542420', 'name': 'Anelyn Delima'},
#                {'gid': '1205218906329431', 'name': 'Rodson Lumayaga'},
#                {'gid': '1203470157870156', 'name': 'Michelle Tuazon'},
#                {'gid': '1206137187789893', 'name': 'Billing Settlement'},
#                {'gid': '1205140945059593', 'name': 'Jessie C. Belegal'},
#                {'gid': '1202571991142942', 'name': 'Joy Monterozo'},
#                {'gid': '1205879828891794', 'name': 'Mae Surban'}],
#  'gid': '1205371003789292',
#  'html_notes': '<body>Stride, a bookkeeping, accounting, and strategic '
#                'advisory services firm, uses Asana to deliver a great client '
#                'experience. By tracking every action item for their clients, '
#                'Stride can build and maintain strong customer relationships. '
#                'Use their template to centralize account management for your '
#                'customers so you can serve them effectively.</body>',
#  'icon': 'list',
#  'members': [{'gid': '1203497384837892', 'name': 'Bryan Dimayuga'},
#              {'gid': '1129267587326102', 'name': 'Michael Angelo H. Lasam'},
#              {'gid': '1205392488469223', 'name': 'Jolina Limosnero'},
#              {'gid': '1202068335503857', 'name': 'Benzell Ann Bathan'},
#              {'gid': '1205676111441160', 'name': 'Raphael Ernesto Tuazon'},
#              {'gid': '1205713538292233', 'name': 'Jason Paquibulan'},
#              {'gid': '1202172752906635', 'name': 'Michael Pluma'},
#              {'gid': '1204664450777161', 'name': 'Ariel B. Bautista'},
#              {'gid': '1205779409810828', 'name': 'Mariadel Bagay'},
#              {'gid': '1205779409810976', 'name': 'Louie Mark Quizon'},
#              {'gid': '1201945980528275',
#               'name': 'teodorico.cortinas@vivant.com.ph'},
#              {'gid': '1200860877542420', 'name': 'Anelyn Delima'},
#              {'gid': '1205218906329431', 'name': 'Rodson Lumayaga'},
#              {'gid': '1203470157870156', 'name': 'Michelle Tuazon'},
#              {'gid': '1206137187789893', 'name': 'Billing Settlement'},
#              {'gid': '1205140945059593', 'name': 'Jessie C. Belegal'},
#              {'gid': '1205879828891794', 'name': 'Mae Surban'},
#              {'gid': '1202571991142942', 'name': 'Joy Monterozo'},
#              {'gid': '1201945980562433', 'name': 'Maureenele Lago'},
#              {'gid': '1206551154582041', 'name': 'Reynold Aropo'}],
#  'minimum_access_level_for_customization': 'admin',
#  'minimum_access_level_for_sharing': 'admin',
#  'modified_at': '2024-02-13T08:33:29.855Z',
#  'name': 'RES| FIXED RATE - LIVE',
#  'notes': 'Stride, a bookkeeping, accounting, and strategic advisory services '
#           'firm, uses Asana to deliver a great client experience. By tracking '
#           'every action item for their clients, Stride can build and maintain '
#           'strong customer relationships. Use their template to centralize '
#           'account management for your customers so you can serve them '
#           'effectively.',
#  'owner': {'gid': '1129267587326102', 'resource_type': 'user'},
#  'permalink_url': 'https://app.asana.com/0/1205371003789292/1205371003789292',
#  'public': False,
#  'start_on': None,
#  'team': {'gid': '1162627753425865', 'name': 'CORE Engineering Services'},
#  'workspace': {'gid': '34545127171843', 'name': 'vivant.com.ph'}}

# %%
api_response.values()
# Out:
# dict_values(['1205371003789292', False, 'light-orange', False, None, None, '2023-08-29T11:55:18.723Z', None, None, [], [{'gid': '1205371003789314', 'custom_field': {'gid': '1205371003789307', 'enum_options': [{'gid': '1205371003789308', 'color': 'yellow-orange', 'enabled': True, 'name': 'Manufacturing'}, {'gid': '1205371003789309', 'color': 'red', 'enabled': False, 'name': 'Bug'}, {'gid': '1205371003789310', 'color': 'green', 'enabled': True, 'name': 'Tourism'}, {'gid': '1205371003789311', 'color': 'indigo', 'enabled': True, 'name': 'Real Estate'}, {'gid': '1205371003789312', 'color': 'blue', 'enabled': True, 'name': 'IT, BPO, Business Services'}, {'gid': '1205371003789313', 'color': 'magenta', 'enabled': True, 'name': 'Healthcare'}, {'gid': '1205371004297372', 'color': 'red', 'enabled': True, 'name': 'Agriculture'}, {'gid': '1205371004297373', 'color': 'orange', 'enabled': True, 'name': 'Government Institution'}, {'gid': '1205371004297374', 'color': 'yellow', 'enabled': True, 'name': 'School or University'}, {'gid': '1205371004297375', 'color': 'yellow-green', 'enabled': True, 'name': 'Construction'}, {'gid': '1205371004297376', 'color': 'blue-green', 'enabled': True, 'name': 'Banking and Finance'}, {'gid': '1205371004297377', 'color': 'aqua', 'enabled': True, 'name': 'Transportation and Storage'}, {'gid': '1205371004297378', 'color': 'purple', 'enabled': True, 'name': 'Hotels and Restaurant'}, {'gid': '1205371004297379', 'color': 'hot-pink', 'enabled': True, 'name': 'Food Process'}, {'gid': '1205376880455346', 'color': 'pink', 'enabled': True, 'name': 'Malls'}, {'gid': '1205376880455361', 'color': 'cool-gray', 'enabled': True, 'name': 'Other Services'}], 'has_notifications_enabled': False, 'name': 'Industry', 'description': 'Category of request the customer is asking for', 'created_by': {'gid': '1203497384837892', 'name': 'Bryan Dimayuga'}, 'resource_subtype': 'enum', 'type': 'enum', 'is_global_to_workspace': True, 'asana_created_field': None, 'is_formula_field': False, 'is_value_read_only': False}, 'is_important': True, 'parent': {'gid': '1205371003789292', 'name': 'RES| FIXED RATE - LIVE'}, 'project': {'gid': '1205371003789292', 'name': 'RES| FIXED RATE - LIVE'}}, {'gid': '1205371004297386', 'custom_field': {'gid': '1205371004297380', 'enum_options': [{'gid': '1205371004297381', 'color': 'green', 'enabled': True, 'name': 'TMC'}, {'gid': '1205371004297382', 'color': 'blue', 'enabled': True, 'name': 'MNL'}, {'gid': '1205371004297383', 'color': 'yellow', 'enabled': True, 'name': 'RRL'}, {'gid': '1205371004297384', 'color': 'green', 'enabled': False, 'name': 'MHL'}, {'gid': '1205371004297385', 'color': 'none', 'enabled': False, 'name': 'LAL'}], 'has_notifications_enabled': False, 'name': 'Account Manager', 'description': '', 'created_by': {'gid': '1203497384837892', 'name': 'Bryan Dimayuga'}, 'resource_subtype': 'enum', 'type': 'enum', 'is_global_to_workspace': False, 'asana_created_field': None, 'is_formula_field': False, 'is_value_read_only': False}, 'is_important': True, 'parent': {'gid': '1205371003789292', 'name': 'RES| FIXED RATE - LIVE'}, 'project': {'gid': '1205371003789292', 'name': 'RES| FIXED RATE - LIVE'}}, {'gid': '1205371004297392', 'custom_field': {'gid': '1205371004297391', 'name': 'Actual', 'description': '', 'created_by': {'gid': '1203497384837892', 'name': 'Bryan Dimayuga'}, 'resource_subtype': 'date', 'type': 'date', 'is_global_to_workspace': False, 'asana_created_field': None, 'is_formula_field': False, 'is_value_read_only': False}, 'is_important': True, 'parent': {'gid': '1205371003789292', 'name': 'RES| FIXED RATE - LIVE'}, 'project': {'gid': '1205371003789292', 'name': 'RES| FIXED RATE - LIVE'}}, {'gid': '1205371004297401', 'custom_field': {'gid': '1205371004297400', 'name': 'Fixed Rate', 'description': '', 'precision': 2, 'format': 'none', 'currency_code': None, 'custom_label': None, 'created_by': {'gid': '1203497384837892', 'name': 'Bryan Dimayuga'}, 'custom_label_position': None, 'resource_subtype':  ...
